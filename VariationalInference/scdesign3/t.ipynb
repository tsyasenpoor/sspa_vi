# %%
import scanpy as sc

adata = sc.read_h5ad('/labs/Aguiar/SSPA_BRAY/BRay/miscc/ctrl_sspa_test/Bcell_GEX_20251201_control.h5ad')

# %%
covid_adata = sc.read_h5ad('/labs/Aguiar/SSPA_BRAY/BRay/BRAY_FileTransfer/Covid19/gm_ctrl_covid.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2049 × 9400
#     obs: 'group', 'condition', 't2dm', 'cvda', 'pt_id', 'comb_id', 'Sex', 'celltype_subclust'
#     var: 'gene_ids', 'feature_types', 'genome', 'mito', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'cell_type_colors', 'cell_type_rank_genes_groups', 'dendrogram_cell_type', 'dendrogram_leiden', 'hvg', 'leiden', 'leiden_colors', 'leiden_rank_genes_groups', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap'
#     varm: 'PCs'
#     layers: 'raw'
#     obsp: 'connectivities', 'distances'

# %%
covid_adata
# Out:
# AnnData object with n_obs × n_vars = 194 × 16408
#     obs: 'sampleID', 'majorType', 'cell_ID'
#     var: 'gene_ids'

# %%
adata.obs
# Out:
#                    group condition  t2dm  cvda pt_id comb_id     Sex  \
# AAAGGTAAGTAGCAAT-1     A      c0d0     0     0    A1      A0  Female
# AACAAAGCATCGTGGC-1     A      c0d0     0     0    A1      A0  Female
# AACCAACGTAGTCTGT-1     A      c0d0     0     0    A1      A0  Female
# AAGCGTTAGGTGAGCT-1     A      c0d0     0     0    A1      A0  Female
# AAGTGAAAGATAACGT-1     A      c0d0     0     0    A1      A0  Female
# ...                  ...       ...   ...   ...   ...     ...     ...
# TTTGGAGAGGTACATA-1     A       NaN     0     0    A8      A8    Male
# TTTGGTTCAAGTGTCT-1     A       NaN     0     0    A4      A4  Female
# TTTGGTTTCTAAGCGT-1     A       NaN     0     0    A8      A8    Male
# TTTGTTGCACCAGTTA-1     A       NaN     0     0    A8      A8    Male
# TTTGTTGTCTAGTGAC-1     A       NaN     0     0    A8      A8    Male
#
#                    celltype_subclust
# AAAGGTAAGTAGCAAT-1            B Cell
# AACAAAGCATCGTGGC-1            B Cell
# AACCAACGTAGTCTGT-1            B Cell
# AAGCGTTAGGTGAGCT-1            B Cell
# AAGTGAAAGATAACGT-1            B Cell
# ...                              ...
# TTTGGAGAGGTACATA-1            B Cell
# TTTGGTTCAAGTGTCT-1            B Cell
# TTTGGTTTCTAAGCGT-1            B Cell
# TTTGTTGCACCAGTTA-1            B Cell
# TTTGTTGTCTAGTGAC-1            B Cell
#
# [2049 rows x 8 columns]

# %%
covid_adata.obs
# Out:
#     sampleID majorType      cell_ID
# 0    S-HC008       CD4    S-HC008_0
# 1    S-HC008        NK    S-HC008_1
# 2    S-HC008       CD8    S-HC008_2
# 3    S-HC008      Mono    S-HC008_3
# 4    S-HC008         B    S-HC008_4
# ..       ...       ...          ...
# 189  S-HC025       CD8  S-HC025_189
# 190  S-HC025      Mono  S-HC025_190
# 191  S-HC025         B  S-HC025_191
# 192  S-HC025        DC  S-HC025_192
# 193  S-HC025      Mega  S-HC025_193
#
# [194 rows x 3 columns]

# %%
adata.var
# Out:
#                         gene_ids    feature_types  genome   mito  \
# ENSG00000188976  ENSG00000188976  Gene Expression  GRCh38  False
# ENSG00000187608  ENSG00000187608  Gene Expression  GRCh38  False
# ENSG00000186891  ENSG00000186891  Gene Expression  GRCh38  False
# ENSG00000078808  ENSG00000078808  Gene Expression  GRCh38  False
# ENSG00000176022  ENSG00000176022  Gene Expression  GRCh38  False
# ...                          ...              ...     ...    ...
# ENSG00000198840  ENSG00000198840  Gene Expression  GRCh38   True
# ENSG00000212907  ENSG00000212907  Gene Expression  GRCh38   True
# ENSG00000198886  ENSG00000198886  Gene Expression  GRCh38   True
# ENSG00000198786  ENSG00000198786  Gene Expression  GRCh38   True
# ENSG00000198695  ENSG00000198695  Gene Expression  GRCh38   True
#
#                  highly_variable     means  dispersions  dispersions_norm
# ENSG00000188976            False  0.198184     1.161064          0.136665
# ENSG00000187608             True  0.611551     2.112126          0.962336
# ENSG00000186891            False  0.082398     1.352114          0.490153
# ENSG00000078808            False  0.423276     1.163203         -0.941575
# ENSG00000176022            False  0.046195     0.946936         -0.259522
# ...                          ...       ...          ...               ...
# ENSG00000198840            False  6.281722     6.465203          1.000000
# ENSG00000212907            False  2.628459     2.866456         -0.830450
# ENSG00000198886            False  5.686319     5.669989         -0.707107
# ENSG00000198786            False  4.288185     4.347731         -1.049132
# ENSG00000198695            False  1.396438     2.119126         -0.280344
#
# [9400 rows x 8 columns]

# %%
covid_adata.var
# Out:
#                         gene_ids
# ENSG00000101811  ENSG00000101811
# ENSG00000004142  ENSG00000004142
# ENSG00000283992  ENSG00000283992
# ENSG00000112619  ENSG00000112619
# ENSG00000143786  ENSG00000143786
# ...                          ...
# ENSG00000157077  ENSG00000157077
# ENSG00000152942  ENSG00000152942
# ENSG00000167232  ENSG00000167232
# ENSG00000157978  ENSG00000157978
# ENSG00000188906  ENSG00000188906
#
# [16408 rows x 1 columns]
